# %% [markdown]
# # Leukemia Classification

# %%
# make connection to google drive to access data
from google.colab import drive
drive.mount('/content/drive')

# %%
# import relevant libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Accessing Data Files in Google Drive

# %%
# # set up directory paths to image files
# train_path = "/content/drive/My Drive/Deep Learning and Generative AI/C-NMC_Leukemia/training_data/fold_0"
# test_path = "/content/drive/My Drive/Deep Learning and Generative AI/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data"
# val_path = "/content/drive/My Drive/Deep Learning and Generative AI/C-NMC_Leukemia/validation_data/val_data"

# %%
combined_path_train = "/content/drive/My Drive/Deep Learning and Generative AI/C-NMC_Leukemia/training_data/fold_0"
combined_path_val = "/content/drive/My Drive/Deep Learning and Generative AI/C-NMC_Leukemia/validation_data/val_data"

# %%
normal_imgs = [] # store normal cell image names
cancer_imgs = [] # store cancer cell image names

for file in os.listdir(combined_path_train+"/hem"): # normal cells
  normal_imgs.append(file)
for file in os.listdir(combined_path_val+"/all"): # cancer cells
  cancer_imgs.append(file)

# %%
len(normal_imgs), len(cancer_imgs)
# Out:
# (2397, 1219)

# %%
image_path = os.path.join(combined_path_train+"\\hem",normal_imgs[2]) # create the full path to the image
img = mpimg.imread(image_path) # read the image data
print(img.shape) # print the shape of the image data
plt.imshow(img) # display the image data
plt.title("Normal Cell", fontsize=14, fontweight='bold')
plt.show()
# Out:
# (369, 369, 4)

# %%
image_path = os.path.join(combined_path_val+"\\all", cancer_imgs[2]) # create the full path to the image
img = mpimg.imread(image_path) # read the image data
print(img.shape) # print the shape of the image data
plt.imshow(img) # display the image data
plt.title("Cancer Cell", fontsize=14, fontweight='bold')
plt.show()
# Out:
# (450, 450, 3)

# %% [markdown]
# ## Image Preprocessing

# %%
dim1 = [] # storing first dimensions of image for analysis
dim2 = [] # storing second dimensions of image for analysis

for image_filename in os.listdir(combined_path_train+'/hem'): # parse through all non-cancer images
    img = mpimg.imread(combined_path_train+'/hem'+'/'+image_filename) # convert image to array
    d1,d2,colors = img.shape # get dimensions of image
    dim1.append(d1) # append to dimension 1 list
    dim2.append(d2) # append to dimension 2 list

for image_filename in os.listdir(combined_path_val+'/all'): # parse through all cancer images
    img = mpimg.imread(combined_path_val+'/all'+'/'+image_filename) # convert image to array
    d1,d2,colors = img.shape # get dimensions of image
    dim1.append(d1) # append to dimension 1 list
    dim2.append(d2) # append to dimension 2 list

# %%
# check for variations in dimensions
np.mean(dim1),np.mean(dim2)
# Out:
# (421.61863938053096, 421.61863938053096)

# %%
# standard shape of image
image_shape = (226,226,1)

# %%
# import library for image manipulation
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# set up generator for image manipulation to add diversity in dataset
image_gen = ImageDataGenerator(rotation_range=20, # rotate 20 degrees
                               width_shift_range=0.10, # shift width by max of 5%
                               height_shift_range=0.10, # shift height by max of 5%
                               rescale=1/255, # rescale image by normalzing
                               shear_range=0.1, # cutting part of image (max 10%)
                               zoom_range=0.1, # zoom by 10% max
                               horizontal_flip=True, # horizontal flip
                               fill_mode='nearest' # fill missing pixels with nearest filled value
                              )

# %%
# rerun this cell as an example of how image is transformed
plt.imshow(image_gen.random_transform(img))

# %% [markdown]
# ## Convolutional Neural Network Model for Image Classification

# %%
# import relevant libraries from tensor flow for model construction
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()  # make sequential model

# add convolutional layers with pooling layers (max pooling)
model.add(Conv2D(filters=32, kernel_size=(3, 3), input_shape=image_shape, activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# flatten output
model.add(Flatten())

# add batch normalization
model.add(BatchNormalization())

# add layer of neurons with 'relu' activation
model.add(Dense(128))
model.add(Activation('relu'))

# add dropout layer, rate=0.5
model.add(Dropout(0.6))

# final output neuron for prediction (cancer or not cancer) with 'sigmoid' activation
model.add(Dense(1))
model.add(Activation('sigmoid'))

# compile model with 'ADAM' optimizer
optimizer = Adam(learning_rate=0.0001)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
# prints out model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 110, 110, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 55, 55, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 53, 53, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 86528)          │       346,112 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    11,075,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,514,625 (43.92 MB)
#  Trainable params: 11,341,569 (43.26 MB)
#  Non-trainable params: 173,056 (676.00 KB)

# %%
# early stopping to monitor validation loss for no improvement
early_stop = EarlyStopping(monitor='val_loss',patience=5)

# %%
batch_size = 32 # to train in batches

# %%
# generator to get training images from combined path
train_image_gen = image_gen.flow_from_directory(combined_path_train,
                                                target_size=(224, 224),
                                                color_mode='grayscale',
                                                batch_size=batch_size,
                                                class_mode='binary')
# Out:
# Found 4794 images belonging to 2 classes.

# %%
# generator to get validation images from combined path
val_image_gen = image_gen.flow_from_directory(combined_path_val,
                                               target_size=(224, 224),
                                               color_mode='grayscale',
                                               batch_size=batch_size,
                                               class_mode='binary',shuffle=False)
# Out:
# Found 2438 images belonging to 2 classes.

# %%
train_image_gen.class_indices # check labels of data
# Out:
# {'all': 0, 'hem': 1}

# %%
val_image_gen.class_indices # check labels of data
# Out:
# {'all': 0, 'hem': 1}

# %%
# suppress any warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# fit the model on dataset
results = model.fit(train_image_gen,epochs=20,validation_data=val_image_gen,callbacks=[early_stop])
# Out:
# Epoch 1/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 132s 846ms/step - accuracy: 0.8010 - loss: 0.4264 - val_accuracy: 0.5328 - val_loss: 0.6082
# Epoch 2/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 122s 801ms/step - accuracy: 0.8428 - loss: 0.3696 - val_accuracy: 0.7260 - val_loss: 0.5325
# Epoch 3/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 122s 806ms/step - accuracy: 0.8524 - loss: 0.3516 - val_accuracy: 0.7391 - val_loss: 0.5755
# Epoch 4/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 120s 789ms/step - accuracy: 0.8384 - loss: 0.3639 - val_accuracy: 0.7293 - val_loss: 0.5519
# Epoch 5/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 120s 789ms/step - accuracy: 0.8501 - loss: 0.3397 - val_accuracy: 0.7465 - val_loss: 0.5248
# Epoch 6/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 128s 835ms/step - accuracy: 0.8509 - loss: 0.3498 - val_accuracy: 0.7596 - val_loss: 0.5280
# Epoch 7/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 127s 831ms/step - accuracy: 0.8443 - loss: 0.3637 - val_accuracy: 0.7580 - val_loss: 0.5925
# Epoch 8/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 123s 811ms/step - accuracy: 0.8565 - loss: 0.3411 - val_accuracy: 0.7510 - val_loss: 0.5687
# Epoch 9/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 124s 812ms/step - accuracy: 0.8509 - loss: 0.3551 - val_accuracy: 0.7092 - val_loss: 0.6522
# Epoch 10/20
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 120s 787ms/step - accuracy: 0.8616 - loss: 0.3485 - val_accuracy: 0.7469 - val_loss: 0.5562

# %%
# # save entire CNN model
# model.save('cnn_balanced_model.keras')

# %%
# # save weights separately
# model.save_weights('cnn_balanced_weights.weights.h5')

# %%
# # import relevant library to store model history as json file
# import json
# with open('cnn_balanced_history.json', 'w') as f:
#     json.dump(results.history, f)

# %%
# # save model architecture to JSON
# with open("cnn_balanced_architecture.json", "w") as json_file:
#     json_file.write(model.to_json())

# %% [markdown]
# ## Model Evaluation

# %%
# store results as dataframe
losses = pd.DataFrame(model.history.history)

# %%
# plot training and validation losses
ax = losses[['loss', 'val_loss']].plot()

# set title and labels
ax.set_title('Training and Validation Losses', fontsize=16, fontweight='bold')
ax.set_xlabel('Epochs', fontsize=12)
ax.set_ylabel('Loss', fontsize=12)

plt.show()

# %%
# plot training and validation accuracies
ax = losses[['accuracy', 'val_accuracy']].plot()

# set title and labels
ax.set_title('Training and Validation Accuracies', fontsize=16, fontweight='bold')
ax.set_xlabel('Epochs', fontsize=12)
ax.set_ylabel('Loss', fontsize=12)

plt.show()

# %%
# metrics that were analyzed during fitting
model.metrics_names
# Out:
# ['loss', 'compile_metrics']

# %%
# example evaluation on validation dataset to get those metrics
model.evaluate(val_image_gen)
# Out:
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 27s 338ms/step - accuracy: 0.7697 - loss: 0.5397
# [0.5542293190956116, 0.7506152391433716]

# %%
# predict on validation dataset
pred_probabilities = model.predict(val_image_gen)
# Out:
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 23s 292ms/step

# %%
# classify predictions in binary method
predictions = pred_probabilities > 0.5
# predictions = (pred > 0.5).astype('int') # another way to do it

# %%
val_image_gen.classes # check labels of data
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
# import relevant libraries for classification metrics and quantitative analysis
from sklearn.metrics import classification_report,confusion_matrix

# %%
# print classification report to understand key metrics
print(classification_report(val_image_gen.classes,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.84      0.77      1219
#            1       0.81      0.68      0.74      1219
#
#     accuracy                           0.76      2438
#    macro avg       0.76      0.76      0.76      2438
# weighted avg       0.76      0.76      0.76      2438

# %%
# print confusion matrix to investigate accurate predictions
print(confusion_matrix(val_image_gen.classes,predictions))
# Out:
# [[1019  200]
#  [ 392  827]]

# %%
# get confusion matrix
cm = confusion_matrix(val_image_gen.classes,predictions)

# extract True Positives, False Negatives, False Positives, True Negatives
TN, FP, FN, TP = cm.ravel()

# calculate sensitivity and specificity
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)

print(f"Sensitivity: {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
# Out:
# Sensitivity: 0.6784
# Specificity: 0.8359

# %%
from sklearn.metrics import roc_auc_score, roc_curve

# calculate AUC-ROC score
auc_roc = roc_auc_score(val_image_gen.classes,predictions)
print(f"AUC-ROC Score: {auc_roc:.8f}")

# compute ROC curve
fpr, tpr, thresholds = roc_curve(val_image_gen.classes,predictions)

# plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='green', lw=2, label=f'ROC curve (AUC = {auc_roc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate',fontsize=12)
plt.ylabel('True Positive Rate',fontsize=12)
plt.title('Receiver Operating Characteristic (ROC) Curve',fontsize=14,fontweight='bold')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# AUC-ROC Score: 0.75717801

# %% [markdown]
# ## Prediction on Testing Data

# %%
# import relevant library for image analysis
from tensorflow.keras.preprocessing import image

# %%
train_imgs = [] # list to store all training image names

for file in os.listdir(combined_path_train+'/hem'): # parse through training directory and get all normal cell images
    train_imgs.append(file)

# %%
# load an example image - can change number
my_image = image.load_img(os.path.join(combined_path_train+'/hem',train_imgs[3]),target_size=image_shape,color_mode='grayscale')

# %%
# plot to see the image of cell
plt.imshow(my_image)

# %%
my_image = image.img_to_array(my_image) # convert from image file to array for prediction

# %%
my_image_array = np.expand_dims(my_image, axis=0)  # Shape becomes (1, 224, 224, 1)

# %%
my_image_array.shape # check shape of image array
# Out:
# (1, 226, 226, 1)

# %%
model.predict(my_image_array) # make prediction on current selected cell - should be normal
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# array([[1.]], dtype=float32)

# %%
train_image_gen.class_indices # definition of indices
# Out:
# {'all': 0, 'hem': 1}
